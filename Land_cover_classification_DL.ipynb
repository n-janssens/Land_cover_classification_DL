# %% [markdown]
# # Land_cover_classification Project
# ## Download the data
# This template downloads the UCM data (both mono and multi-labels) in your local Colab environment.

# %%
# install required modules
# !pip install Keras-Applications
# Out:
# Collecting Keras-Applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 2.9 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from Keras-Applications) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras-Applications) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->Keras-Applications) (1.5.2)
# Installing collected packages: Keras-Applications
# Successfully installed Keras-Applications-1.0.8

# %%
# import required modules
from contextlib import suppress
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns
import os
import zipfile
import warnings
from zipfile import ZipFile
from keras.callbacks import TensorBoard
from time import time

from skimage.io import imread, imsave
from fastai.vision import *
from fastai.callbacks import CSVLogger, SaveModelCallback
import keras
from keras import applications
from keras import optimizers
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from IPython.display import clear_output
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
from sklearn.metrics import accuracy_score, classification_report

# %matplotlib inline

# %%
# import required data
! git clone https://git.wur.nl/lobry001/ucmdata.git
os.chdir('ucmdata')

with zipfile.ZipFile('UCMerced_LandUse.zip', 'r') as zip_ref:
    zip_ref.extractall('UCMImages')

# !mv UCMImages/UCMerced_LandUse/Images .
# !rm -rf UCMImages README.md  UCMerced_LandUse.zip
# !ls

UCM_images_path = "Images/"
Multilabels_path = "LandUse_Multilabeled.txt"
source_dir = os.path.join('/content', 'ucmdata', 'Images/')
# Out:
# Cloning into 'ucmdata'...
# remote: Enumerating objects: 8, done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 8
# Unpacking objects: 100% (8/8), done.
# Images	LandUse_Multilabeled.txt

# %%
# Set random seed for reproducibility
np.random.seed(8)

# %%
# create image directory hierarchy: Train, test and Validate folders

# Collect class names from directory names in './data/UCMerced_LandUse/Images/'
class_names = os.listdir(source_dir)    

# Create path to image "flow" base directory
flow_base = os.path.join('/content', 'flow')

# Create pathnames to train/validate/test subdirectories
target_dirs = {target: os.path.join(flow_base, target) for target in ['train', 'validate', 'test']}

if not os.path.isdir(flow_base):

    # Make new directories
    os.mkdir(flow_base)
    
    for target in ['train', 'validate', 'test']:
        target_dir = os.path.join(flow_base, target)
        os.mkdir(target_dir)
        for class_name in class_names:
            class_subdir = os.path.join(target_dir, class_name)
            os.mkdir(class_subdir)

    # suppress low-contrast warning from skimage.io.imsave
    warnings.simplefilter('ignore', UserWarning)
    
    # Copy images from ./data/UCMerced_LandUse/Images to ./content/flow/<train, validate, test>    
    for root, _, filenames in os.walk(source_dir):
        if filenames:
            class_name = os.path.basename(root)
          
            # Randomly shuffle filenames
            filenames = np.random.permutation(filenames)
            for target, count in [('train', 80), ('validate', 10), ('test', 10)]:
                target_dir = os.path.join(flow_base, target, class_name)
                for filename in filenames[:count]:
                    filepath = os.path.join(root, filename)
                    image = imread(filepath)
                    basename, _ = os.path.splitext(filename)

                    # Convert TIF to PNG to work with Keras ImageDataGenerator.flow_from_directory
                    target_filename = os.path.join(target_dir, basename + '.png')
                    imsave(target_filename, image)

                filenames = filenames[count:]

               

    # Show future warnings during development
    warnings.resetwarnings()

# %%
# calculate means for all channels in images in training folder
# these can be used to normalize the image values before training
means = []
for root, _, filenames in os.walk(target_dirs['train']):
    for filename in filenames:
        filepath = os.path.join(root, filename)
        image = imread(filepath)
        means.append(np.mean(image, axis=(0, 1)))
channel_means = np.mean(means, axis=0)

# %%
# Get bottleneck_features X and Labels Y for the input dataset (train/test/validate)

def get_bottleneck_features(model, dataset, preproc_func, batch_size=64):
    """
    by predicting on the convolutional portion only of a pretrained model.
       
    Inputs:
        model: Pre-trained deep learning model, excluding fully-connected top model
               e.g. applications.VGG16(include_top=False, weights='imagenet')
        dataset = string label for dataset image directory ['train', 'validate', 'test']
        preproc_func: preprocessing function implied to each input sample
        batch_size: number of image samples per batch
    
    Return:
        Return bottleneck features as numpy.array
    """
    print(f'Generating "{dataset}" bottleneck predictions')
    X_filepath = os.path.join('/content/flow', 'bn_' + dataset + '_X.npy')
    y_filepath = os.path.join('/content/flow', 'bn_' + dataset + '_y.npy')

    # Check if data are available from disk.
    try:
        with open(X_filepath, 'rb') as f:
            X = np.load(f)
        with open(y_filepath, 'rb') as f:
            y = np.load(f)
            Y = to_categorical(y, num_classes=len(np.unique(y)))
    # Else, get the bottleneck features and labels
    except:
        image_data_gen = ImageDataGenerator(rescale=1/224.0, preprocessing_function=preproc_func)
        image_generator = image_data_gen.flow_from_directory(target_dirs[dataset],
                                                             batch_size=batch_size,
                                                             shuffle=False)
        image_count = 0
        X_batches, Y_batches = [], []
        for X, Y in image_generator:
            X_batches.append(model.predict_on_batch(X))
            Y_batches.append(Y)
            image_count += X.shape[0]
            # Must interrupt image_generator
            if image_count >= image_generator.n:
                break

        X = np.concatenate(X_batches)
        with open(X_filepath, 'wb') as f:
            np.save(f, X) 
        Y = np.concatenate(Y_batches)
        y = np.nonzero(Y)[1]
        with open(y_filepath, 'wb') as f:
            np.save(f, y)
    
    print(f'   Features of shape {X.shape} extracted for model "{model.name}"')
    return X, Y

# %% [markdown]
# # Single-Label classification
# In this section, we are performing the single-label classification.

# %%
# insert settings for model

# dropout
dropout = 0

# learning rate
lr = 0.0001

# batch_size
bs = 64

# number of epochs
epochs = 100

# %%
# Load all the required pre trained models
#cnn = VGG16(include_top=False, weights='imagenet')
cnn = ResNet152V2(include_top=False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234553344/234545216 [==============================] - 2s 0us/step

# %%
# extract bottleneck features from pretrained model
# change input model in line 8 and choose between vgg_model or resnet_model
num_classes = len(class_names)
X, Y = dict(), dict()
preprocess = lambda x: x - channel_means
for dataset in ['train', 'validate', 'test']:
    # Extract bottleneck features from pretrained model, predicting from "dataset" directory
    X[dataset], Y[dataset] = get_bottleneck_features(cnn, dataset, preprocess)
# Out:
# Generating "train" bottleneck predictions
# Found 1680 images belonging to 21 classes.
#    Features of shape (1680, 8, 8, 2048) extracted for model "resnet152v2"
# Generating "validate" bottleneck predictions
# Found 210 images belonging to 21 classes.
#    Features of shape (210, 8, 8, 2048) extracted for model "resnet152v2"
# Generating "test" bottleneck predictions
# Found 210 images belonging to 21 classes.
#    Features of shape (210, 8, 8, 2048) extracted for model "resnet152v2"

# %%
# build a classifier model to put on top of the convolutional model
def build_fully_connected(model, input_shape, num_classes):
    """
    Create a fully-connected model to train or test on UC Merced dataset.
    """
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(dropout))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
model = build_fully_connected(cnn, input_shape=X['train'].shape[1:], num_classes=num_classes)
adam = optimizers.Adam(lr=lr)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(X['train'], Y['train'], batch_size=bs, epochs=epochs,
                              verbose=2, validation_data=(X['validate'], Y['validate']))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/100
# 27/27 - 13s - loss: 0.8464 - accuracy: 0.7625 - val_loss: 0.4180 - val_accuracy: 0.8810
# Epoch 2/100
# 27/27 - 1s - loss: 0.0224 - accuracy: 0.9917 - val_loss: 0.3423 - val_accuracy: 0.9048
# Epoch 3/100
# 27/27 - 1s - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.3284 - val_accuracy: 0.9048
# Epoch 4/100
# 27/27 - 1s - loss: 2.1227e-04 - accuracy: 1.0000 - val_loss: 0.3264 - val_accuracy: 0.9143
# Epoch 5/100
# 27/27 - 1s - loss: 1.1129e-04 - accuracy: 1.0000 - val_loss: 0.3213 - val_accuracy: 0.9143
# Epoch 6/100
# 27/27 - 1s - loss: 9.1043e-05 - accuracy: 1.0000 - val_loss: 0.3195 - val_accuracy: 0.9143
# Epoch 7/100
# 27/27 - 1s - loss: 7.8719e-05 - accuracy: 1.0000 - val_loss: 0.3181 - val_accuracy: 0.9143
# Epoch 8/100
# 27/27 - 1s - loss: 6.9373e-05 - accuracy: 1.0000 - val_loss: 0.3171 - val_accuracy: 0.9143
# Epoch 9/100
# 27/27 - 1s - loss: 6.2246e-05 - accuracy: 1.0000 - val_loss: 0.3165 - val_accuracy: 0.9143
# Epoch 10/100
# 27/27 - 1s - loss: 5.6316e-05 - accuracy: 1.0000 - val_loss: 0.3159 - val_accuracy: 0.9143
# Epoch 11/100
# 27/27 - 1s - loss: 5.1384e-05 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.9143
# Epoch 12/100
# 27/27 - 1s - loss: 4.7207e-05 - accuracy: 1.0000 - val_loss: 0.3148 - val_accuracy: 0.9143
# Epoch 13/100
# 27/27 - 1s - loss: 4.3487e-05 - accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.9143
# Epoch 14/100
# 27/27 - 1s - loss: 4.0204e-05 - accuracy: 1.0000 - val_loss: 0.3137 - val_accuracy: 0.9143
# Epoch 15/100
# 27/27 - 1s - loss: 3.7401e-05 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9143
# Epoch 16/100
# 27/27 - 1s - loss: 3.4882e-05 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9095
# Epoch 17/100
# 27/27 - 1s - loss: 3.2646e-05 - accuracy: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9095
# Epoch 18/100
# 27/27 - 1s - loss: 3.0656e-05 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9048
# Epoch 19/100
# 27/27 - 1s - loss: 2.8866e-05 - accuracy: 1.0000 - val_loss: 0.3127 - val_accuracy: 0.9048
# Epoch 20/100
# 27/27 - 1s - loss: 2.7215e-05 - accuracy: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.9048
# Epoch 21/100
# 27/27 - 1s - loss: 2.5676e-05 - accuracy: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.9048
# Epoch 22/100
# 27/27 - 1s - loss: 2.4292e-05 - accuracy: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.9048
# Epoch 23/100
# 27/27 - 1s - loss: 2.3001e-05 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9048
# Epoch 24/100
# 27/27 - 1s - loss: 2.1845e-05 - accuracy: 1.0000 - val_loss: 0.3124 - val_accuracy: 0.9048
# Epoch 25/100
# 27/27 - 1s - loss: 2.0749e-05 - accuracy: 1.0000 - val_loss: 0.3124 - val_accuracy: 0.9048
# Epoch 26/100
# 27/27 - 1s - loss: 1.9756e-05 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9048
# Epoch 27/100
# 27/27 - 1s - loss: 1.8840e-05 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9048
# Epoch 28/100
# 27/27 - 1s - loss: 1.7991e-05 - accuracy: 1.0000 - val_loss: 0.3122 - val_accuracy: 0.9048
# Epoch 29/100
# 27/27 - 1s - loss: 1.7200e-05 - accuracy: 1.0000 - val_loss: 0.3122 - val_accuracy: 0.9048
# Epoch 30/100
# 27/27 - 1s - loss: 1.6473e-05 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9048
# Epoch 31/100
# 27/27 - 1s - loss: 1.5775e-05 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9048
# Epoch 32/100
# 27/27 - 1s - loss: 1.5114e-05 - accuracy: 1.0000 - val_loss: 0.3122 - val_accuracy: 0.9048
# Epoch 33/100
# 27/27 - 1s - loss: 1.4504e-05 - accuracy: 1.0000 - val_loss: 0.3122 - val_accuracy: 0.9048
# Epoch 34/100
# 27/27 - 1s - loss: 1.3942e-05 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9048
# Epoch 35/100
# 27/27 - 1s - loss: 1.3426e-05 - accuracy: 1.0000 - val_loss: 0.3122 - val_accuracy: 0.9048
# Epoch 36/100
# 27/27 - 1s - loss: 1.2944e-05 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9048
# Epoch 37/100
# 27/27 - 1s - loss: 1.2486e-05 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9048
# Epoch 38/100
# 27/27 - 1s - loss: 1.2016e-05 - accuracy: 1.0000 - val_loss: 0.3124 - val_accuracy: 0.9048
# Epoch 39/100
# 27/27 - 1s - loss: 1.1599e-05 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9048
# Epoch 40/100
# 27/27 - 1s - loss: 1.1213e-05 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9048
# Epoch 41/100
# 27/27 - 1s - loss: 1.0842e-05 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9048
# Epoch 42/100
# 27/27 - 1s - loss: 1.0478e-05 - accuracy: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.9048
# Epoch 43/100
# 27/27 - 1s - loss: 1.0145e-05 - accuracy: 1.0000 - val_loss: 0.3127 - val_accuracy: 0.9048
# Epoch 44/100
# 27/27 - 1s - loss: 9.8170e-06 - accuracy: 1.0000 - val_loss: 0.3127 - val_accuracy: 0.9048
# Epoch 45/100
# 27/27 - 1s - loss: 9.5093e-06 - accuracy: 1.0000 - val_loss: 0.3128 - val_accuracy: 0.9048
# Epoch 46/100
# 27/27 - 1s - loss: 9.2264e-06 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9048
# Epoch 47/100
# 27/27 - 1s - loss: 8.9472e-06 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9048
# Epoch 48/100
# 27/27 - 1s - loss: 8.6746e-06 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9048
# Epoch 49/100
# 27/27 - 1s - loss: 8.4245e-06 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9048
# Epoch 50/100
# 27/27 - 1s - loss: 8.1837e-06 - accuracy: 1.0000 - val_loss: 0.3132 - val_accuracy: 0.9048
# Epoch 51/100
# 27/27 - 1s - loss: 7.9451e-06 - accuracy: 1.0000 - val_loss: 0.3133 - val_accuracy: 0.9048
# Epoch 52/100
# 27/27 - 1s - loss: 7.7164e-06 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9048
# Epoch 53/100
# 27/27 - 1s - loss: 7.5019e-06 - accuracy: 1.0000 - val_loss: 0.3137 - val_accuracy: 0.9048
# Epoch 54/100
# 27/27 - 1s - loss: 7.2958e-06 - accuracy: 1.0000 - val_loss: 0.3137 - val_accuracy: 0.9048
# Epoch 55/100
# 27/27 - 1s - loss: 7.1035e-06 - accuracy: 1.0000 - val_loss: 0.3138 - val_accuracy: 0.9048
# Epoch 56/100
# 27/27 - 1s - loss: 6.9126e-06 - accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9048
# Epoch 57/100
# 27/27 - 1s - loss: 6.7299e-06 - accuracy: 1.0000 - val_loss: 0.3139 - val_accuracy: 0.9048
# Epoch 58/100
# 27/27 - 1s - loss: 6.5565e-06 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.9048
# Epoch 59/100
# 27/27 - 1s - loss: 6.3894e-06 - accuracy: 1.0000 - val_loss: 0.3142 - val_accuracy: 0.9048
# Epoch 60/100
# 27/27 - 1s - loss: 6.2175e-06 - accuracy: 1.0000 - val_loss: 0.3143 - val_accuracy: 0.9048
# Epoch 61/100
# 27/27 - 1s - loss: 6.0646e-06 - accuracy: 1.0000 - val_loss: 0.3144 - val_accuracy: 0.9048
# Epoch 62/100
# 27/27 - 1s - loss: 5.9048e-06 - accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.9048
# Epoch 63/100
# 27/27 - 1s - loss: 5.7588e-06 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9048
# Epoch 64/100
# 27/27 - 1s - loss: 5.6138e-06 - accuracy: 1.0000 - val_loss: 0.3148 - val_accuracy: 0.9048
# Epoch 65/100
# 27/27 - 1s - loss: 5.4664e-06 - accuracy: 1.0000 - val_loss: 0.3149 - val_accuracy: 0.9048
# Epoch 66/100
# 27/27 - 1s - loss: 5.3357e-06 - accuracy: 1.0000 - val_loss: 0.3150 - val_accuracy: 0.9048
# Epoch 67/100
# 27/27 - 1s - loss: 5.2105e-06 - accuracy: 1.0000 - val_loss: 0.3150 - val_accuracy: 0.9048
# Epoch 68/100
# 27/27 - 1s - loss: 5.0859e-06 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.9048
# Epoch 69/100
# 27/27 - 1s - loss: 4.9663e-06 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.9048
# Epoch 70/100
# 27/27 - 1s - loss: 4.8509e-06 - accuracy: 1.0000 - val_loss: 0.3153 - val_accuracy: 0.9048
# Epoch 71/100
# 27/27 - 1s - loss: 4.7389e-06 - accuracy: 1.0000 - val_loss: 0.3154 - val_accuracy: 0.9048
# Epoch 72/100
# 27/27 - 1s - loss: 4.6299e-06 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.9048
# Epoch 73/100
# 27/27 - 1s - loss: 4.5256e-06 - accuracy: 1.0000 - val_loss: 0.3156 - val_accuracy: 0.9048
# Epoch 74/100
# 27/27 - 1s - loss: 4.4249e-06 - accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9048
# Epoch 75/100
# 27/27 - 1s - loss: 4.3261e-06 - accuracy: 1.0000 - val_loss: 0.3159 - val_accuracy: 0.9048
# Epoch 76/100
# 27/27 - 1s - loss: 4.2337e-06 - accuracy: 1.0000 - val_loss: 0.3160 - val_accuracy: 0.9048
# Epoch 77/100
# 27/27 - 1s - loss: 4.1421e-06 - accuracy: 1.0000 - val_loss: 0.3162 - val_accuracy: 0.9048
# Epoch 78/100
# 27/27 - 1s - loss: 4.0481e-06 - accuracy: 1.0000 - val_loss: 0.3163 - val_accuracy: 0.9048
# Epoch 79/100
# 27/27 - 1s - loss: 3.9598e-06 - accuracy: 1.0000 - val_loss: 0.3164 - val_accuracy: 0.9048
# Epoch 80/100
# 27/27 - 1s - loss: 3.8747e-06 - accuracy: 1.0000 - val_loss: 0.3166 - val_accuracy: 0.9048
# Epoch 81/100
# 27/27 - 1s - loss: 3.7900e-06 - accuracy: 1.0000 - val_loss: 0.3167 - val_accuracy: 0.9048
# Epoch 82/100
# 27/27 - 1s - loss: 3.7106e-06 - accuracy: 1.0000 - val_loss: 0.3169 - val_accuracy: 0.9048
# Epoch 83/100
# 27/27 - 1s - loss: 3.6304e-06 - accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9048
# Epoch 84/100
# 27/27 - 1s - loss: 3.5550e-06 - accuracy: 1.0000 - val_loss: 0.3172 - val_accuracy: 0.9048
# Epoch 85/100
# 27/27 - 1s - loss: 3.4807e-06 - accuracy: 1.0000 - val_loss: 0.3173 - val_accuracy: 0.9048
# Epoch 86/100
# 27/27 - 1s - loss: 3.4097e-06 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.9048
# Epoch 87/100
# 27/27 - 1s - loss: 3.3403e-06 - accuracy: 1.0000 - val_loss: 0.3176 - val_accuracy: 0.9048
# Epoch 88/100
# 27/27 - 1s - loss: 3.2720e-06 - accuracy: 1.0000 - val_loss: 0.3177 - val_accuracy: 0.9048
# Epoch 89/100
# 27/27 - 1s - loss: 3.2056e-06 - accuracy: 1.0000 - val_loss: 0.3178 - val_accuracy: 0.9048
# Epoch 90/100
# 27/27 - 1s - loss: 3.1421e-06 - accuracy: 1.0000 - val_loss: 0.3179 - val_accuracy: 0.9048
# Epoch 91/100
# 27/27 - 1s - loss: 3.0802e-06 - accuracy: 1.0000 - val_loss: 0.3180 - val_accuracy: 0.9048
# Epoch 92/100
# 27/27 - 1s - loss: 3.0210e-06 - accuracy: 1.0000 - val_loss: 0.3181 - val_accuracy: 0.9048
# Epoch 93/100
# 27/27 - 1s - loss: 2.9620e-06 - accuracy: 1.0000 - val_loss: 0.3182 - val_accuracy: 0.9048
# Epoch 94/100
# 27/27 - 1s - loss: 2.9048e-06 - accuracy: 1.0000 - val_loss: 0.3184 - val_accuracy: 0.9048
# Epoch 95/100
# 27/27 - 1s - loss: 2.8489e-06 - accuracy: 1.0000 - val_loss: 0.3185 - val_accuracy: 0.9048
# Epoch 96/100
# 27/27 - 1s - loss: 2.7945e-06 - accuracy: 1.0000 - val_loss: 0.3187 - val_accuracy: 0.9048
# Epoch 97/100
# 27/27 - 1s - loss: 2.7428e-06 - accuracy: 1.0000 - val_loss: 0.3188 - val_accuracy: 0.9048
# Epoch 98/100
# 27/27 - 1s - loss: 2.6886e-06 - accuracy: 1.0000 - val_loss: 0.3189 - val_accuracy: 0.9048
# Epoch 99/100
# 27/27 - 1s - loss: 2.6393e-06 - accuracy: 1.0000 - val_loss: 0.3190 - val_accuracy: 0.9048
# Epoch 100/100
# 27/27 - 1s - loss: 2.5893e-06 - accuracy: 1.0000 - val_loss: 0.3191 - val_accuracy: 0.9048

# %%
epochs = np.argmin(model_fit_history.history['val_loss']) + 1
print(f'Stop training at {epochs} epochs')

# Merge training and validation data
X_train = np.concatenate([X['train'], X['validate']])
Y_train = np.concatenate([Y['train'], Y['validate']])

# Randomly shuffle X and Y
shuffle_index = np.random.permutation(len(X_train))
X_train = X_train[shuffle_index]
Y_train = Y_train[shuffle_index]
model = build_fully_connected(cnn, input_shape=X_train.shape[1:], num_classes=num_classes)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(X_train, Y_train, batch_size=bs, epochs=epochs, verbose=0)
# Out:
# Stop training at 29 epochs

# %%
# Flatten Y into a vector
y_test = np.nonzero(Y['test'])[1]

# Predict on the test images
y_pred = model.predict_classes(X['test'], verbose=0)

accuracy = accuracy_score(y_test, y_pred)
print(f'Model predication accuracy: {accuracy:.3f}')
print(f'\nClassification report:\n {classification_report(y_test, y_pred)}')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Model predication accuracy: 0.919
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        10
#            1       0.91      1.00      0.95        10
#            2       1.00      0.90      0.95        10
#            3       1.00      1.00      1.00        10
#            4       0.90      0.90      0.90        10
#            5       1.00      1.00      1.00        10
#            6       0.88      0.70      0.78        10
#            7       1.00      1.00      1.00        10
#            8       0.90      0.90      0.90        10
#            9       0.91      1.00      0.95        10
#           10       1.00      1.00      1.00        10
#           11       1.00      0.70      0.82        10
#           12       0.71      1.00      0.83        10
#           13       1.00      0.90      0.95        10
#           14       1.00      0.90      0.95        10
#           15       0.91      1.00      0.95        10
#           16       0.91      1.00      0.95        10
#           17       1.00      1.00      1.00        10
#           18       0.89      0.80      0.84        10
#           19       0.75      0.90      0.82        10
#           20       0.88      0.70      0.78        10
#
#     accuracy                           0.92       210
#    macro avg       0.93      0.92      0.92       210
# weighted avg       0.93      0.92      0.92       210

# %% [markdown]
# # Multi-Label classification
# In this section, we are performing the multi-label classification.

# %%
# insert settings for model
# learning rate
lr = 0.01

# batch_size
bs = 16

# number of epochs
epochs = 50

# image size
size = 224

# %%
# load Landuse_Multilabeled classes
df = pd.read_csv("/content/ucmdata/LandUse_Multilabeled.txt", sep="\t")
df.head()

# Create Class count dataframe
class_count = pd.DataFrame(df.sum(axis=0)).reset_index()
class_count.columns = ["class", "Count"]
class_count.drop(class_count.index[0], inplace=True)

# loop through Images subfolder and place all .tif files in Images folder
# this is a required step for adding the multilabels to images
for root, dirs, files in os.walk(os.path.abspath("/content/ucmdata/Images")):
    for file in files:
        shutil.move(os.path.join(root, file), os.path.join("/content/ucmdata/Images", file))

# fastai function that merges multilabels with images
data_src = (ImageList.from_df(df=df, path="/content/ucmdata", folder = 'Images', suffix=".tif")
        .split_by_rand_pct(0.2)
        .label_from_df(list(class_count['class']),  label_cls=MultiCategoryList, one_hot=True))

# transform images, give them the correct size and show examples
tfms = get_transforms(do_flip = True, flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)
data = (data_src.transform(tfms, size=size).databunch().normalize(imagenet_stats))
data.batch_size = bs
data.show_batch(2)

# %%
f_score = partial(fbeta, thresh=0.2)

learn = cnn_learner(data, models.resnet152, metrics=[accuracy_thresh, f_score], pretrained=True,
                    callback_fns=[ShowGraph, SaveModelCallback])

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='92' class='' max='105' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       87.62% [92/105 00:58<00:08 2.8632]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn = learn.to_fp16()
learn.fit_one_cycle(epochs, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.670496</td>
#       <td>0.433961</td>
#       <td>0.816246</td>
#       <td>0.618502</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.484152</td>
#       <td>0.271135</td>
#       <td>0.921148</td>
#       <td>0.731148</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.291016</td>
#       <td>0.153388</td>
#       <td>0.944958</td>
#       <td>0.892152</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.191968</td>
#       <td>0.131866</td>
#       <td>0.946499</td>
#       <td>0.905924</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.161573</td>
#       <td>0.126151</td>
#       <td>0.947899</td>
#       <td>0.899348</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.146878</td>
#       <td>0.117340</td>
#       <td>0.951401</td>
#       <td>0.918835</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.145790</td>
#       <td>0.127836</td>
#       <td>0.949160</td>
#       <td>0.901258</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.145480</td>
#       <td>0.128318</td>
#       <td>0.949300</td>
#       <td>0.909727</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.139303</td>
#       <td>0.134241</td>
#       <td>0.947619</td>
#       <td>0.901825</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.131657</td>
#       <td>0.122250</td>
#       <td>0.954202</td>
#       <td>0.920750</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.126494</td>
#       <td>0.122016</td>
#       <td>0.951821</td>
#       <td>0.908266</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.136316</td>
#       <td>0.122532</td>
#       <td>0.954482</td>
#       <td>0.916400</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.127877</td>
#       <td>0.122602</td>
#       <td>0.956163</td>
#       <td>0.917592</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.116815</td>
#       <td>0.101324</td>
#       <td>0.959524</td>
#       <td>0.934718</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.113383</td>
#       <td>0.101764</td>
#       <td>0.959104</td>
#       <td>0.928878</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.111890</td>
#       <td>0.129224</td>
#       <td>0.955042</td>
#       <td>0.920638</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.112000</td>
#       <td>0.132577</td>
#       <td>0.956443</td>
#       <td>0.916961</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.107787</td>
#       <td>0.116677</td>
#       <td>0.957563</td>
#       <td>0.924027</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.100418</td>
#       <td>0.108279</td>
#       <td>0.957143</td>
#       <td>0.928544</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.096484</td>
#       <td>0.103460</td>
#       <td>0.960364</td>
#       <td>0.931899</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.096457</td>
#       <td>0.105650</td>
#       <td>0.960364</td>
#       <td>0.936715</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.091481</td>
#       <td>0.097073</td>
#       <td>0.963305</td>
#       <td>0.933235</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.093769</td>
#       <td>0.091520</td>
#       <td>0.964286</td>
#       <td>0.939458</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.095889</td>
#       <td>0.096461</td>
#       <td>0.962745</td>
#       <td>0.939904</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.088400</td>
#       <td>0.091798</td>
#       <td>0.966247</td>
#       <td>0.940114</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.084826</td>
#       <td>0.103988</td>
#       <td>0.963725</td>
#       <td>0.932167</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.077229</td>
#       <td>0.088389</td>
#       <td>0.966947</td>
#       <td>0.942127</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.076911</td>
#       <td>0.096884</td>
#       <td>0.963305</td>
#       <td>0.934767</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.071677</td>
#       <td>0.091950</td>
#       <td>0.967927</td>
#       <td>0.936604</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.075026</td>
#       <td>0.096620</td>
#       <td>0.965826</td>
#       <td>0.938209</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.066131</td>
#       <td>0.098222</td>
#       <td>0.965126</td>
#       <td>0.937544</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.067455</td>
#       <td>0.091735</td>
#       <td>0.966667</td>
#       <td>0.941176</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.060112</td>
#       <td>0.098753</td>
#       <td>0.965126</td>
#       <td>0.937860</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.059694</td>
#       <td>0.094907</td>
#       <td>0.967087</td>
#       <td>0.935804</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.063302</td>
#       <td>0.094195</td>
#       <td>0.966246</td>
#       <td>0.942328</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.060479</td>
#       <td>0.094450</td>
#       <td>0.967367</td>
#       <td>0.942437</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.056000</td>
#       <td>0.100180</td>
#       <td>0.964566</td>
#       <td>0.940163</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.053659</td>
#       <td>0.101690</td>
#       <td>0.965966</td>
#       <td>0.942580</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.052145</td>
#       <td>0.099018</td>
#       <td>0.967787</td>
#       <td>0.941167</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.049660</td>
#       <td>0.098542</td>
#       <td>0.968347</td>
#       <td>0.944705</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.049043</td>
#       <td>0.096845</td>
#       <td>0.967647</td>
#       <td>0.941349</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.041791</td>
#       <td>0.099917</td>
#       <td>0.966667</td>
#       <td>0.942782</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.045216</td>
#       <td>0.101021</td>
#       <td>0.966947</td>
#       <td>0.940101</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.042152</td>
#       <td>0.099680</td>
#       <td>0.966247</td>
#       <td>0.943001</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.042011</td>
#       <td>0.099958</td>
#       <td>0.967227</td>
#       <td>0.940108</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.037678</td>
#       <td>0.099928</td>
#       <td>0.967647</td>
#       <td>0.938780</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.042875</td>
#       <td>0.098631</td>
#       <td>0.966807</td>
#       <td>0.940827</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.035633</td>
#       <td>0.097333</td>
#       <td>0.968067</td>
#       <td>0.939873</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.038873</td>
#       <td>0.098436</td>
#       <td>0.966667</td>
#       <td>0.942145</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.041409</td>
#       <td>0.100537</td>
#       <td>0.966246</td>
#       <td>0.941318</td>
#       <td>01:11</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.43396127223968506.
# Better model found at epoch 1 with valid_loss value: 0.271134614944458.
# Better model found at epoch 2 with valid_loss value: 0.1533876359462738.
# Better model found at epoch 3 with valid_loss value: 0.1318656951189041.
# Better model found at epoch 4 with valid_loss value: 0.1261511892080307.
# Better model found at epoch 5 with valid_loss value: 0.1173396036028862.
# Better model found at epoch 13 with valid_loss value: 0.10132424533367157.
# Better model found at epoch 21 with valid_loss value: 0.097072534263134.
# Better model found at epoch 22 with valid_loss value: 0.0915202647447586.
# Better model found at epoch 26 with valid_loss value: 0.088389091193676.

# %%
learn.save('stage-1')

# %%
learn.unfreeze()
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='57' class='' max='105' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       54.29% [57/105 00:51<00:43 0.1764]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, slice(1e-5, lr/5))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.00% [3/10 05:08<11:58]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.067400</td>
#       <td>0.091036</td>
#       <td>0.968207</td>
#       <td>0.943364</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.095354</td>
#       <td>0.121605</td>
#       <td>0.957563</td>
#       <td>0.927297</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.120453</td>
#       <td>0.114500</td>
#       <td>0.957003</td>
#       <td>0.913432</td>
#       <td>01:41</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='73' class='' max='105' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       69.52% [73/105 01:05<00:28 0.1058]
#     </div>
# Better model found at epoch 0 with valid_loss value: 0.0910358801484108.

# %%
learn.show_results(figsize=(20,20))
